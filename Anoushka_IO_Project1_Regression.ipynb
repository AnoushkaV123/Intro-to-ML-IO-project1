# %% [markdown]
# <a href="https://colab.research.google.com/github/AnoushkaV123/Intro-to-ML-IO-project1/blob/main/Anoushka_IO_Project1_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Project 1: regression

#importing modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model
regr = linear_model.LinearRegression()

#importing the file (dataset)
file_name='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/kc_house_data_NaN.csv'
dff=pd.read_csv(file_name)
dff.head()
dff.describe()
dff.drop(['id','Unnamed: 0'],inplace=True,axis=1)
dff.describe()

##### set 1 #####
cdf = dff[['price','grade']]

from sklearn.model_selection import train_test_split
X_train1,X_test1,y_train1,y_test1=train_test_split(cdf,cdf,test_size=.2,random_state=4);

from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x1 = np.asanyarray(X_train1[['grade']])
train_y1 = np.asanyarray(X_train1[['price']])
regr.fit(train_x1, train_y1)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)

plt.scatter(X_train1.grade, X_train1.price  ,  color='blue')
plt.plot(train_x1, regr.coef_[0][0]*train_x1 + regr.intercept_[0], '-r')
plt.xlabel("Grade allotted")
plt.ylabel("Price")

test_x = np.asanyarray(X_test[['grade']])
test_y = np.asanyarray(X_test[['price']]) #this is the y' (predicted value)
test_y_ = regr.predict(test_x) # predict is a keyword from sk learn module
mae= np.mean(np.absolute(test_y_ - test_y))
mae_=mae/21613
mse=np.mean((test_y_ - test_y) ** 2)
mse_=mse/21613
print("Mean absolute error: " , mae_)
print("Residual sum of squares (MSE): " ,mse_ )
# Out:
# Coefficients:  [[209349.23305535]]
# Intercept:  [-1062636.76835037]
# Mean absolute error:  8.06806253753839
# Residual sum of squares (MSE):  3326854.9254775858

# %%
cdf = dff[['price','sqft_lot']]

from sklearn.model_selection import train_test_split
X_train1,X_test1,y_train1,y_test1=train_test_split(cdf,cdf,test_size=.2,random_state=4);

from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x1 = np.asanyarray(X_train1[['sqft_lot']])
train_y1 = np.asanyarray(X_train1[['price']])
regr.fit(train_x1, train_y1)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)

plt.scatter(X_train1.sqft_lot, X_train1.price  ,  color='blue')
plt.plot(train_x1, regr.coef_[0][0]*train_x1 + regr.intercept_[0], '-r')
plt.xlabel("Sqft_lot")
plt.ylabel("Price")
test_x = np.asanyarray(X_test[['sqft_lot']])
test_y = np.asanyarray(X_test[['price']]) #this is the y' (predicted value)
test_y_ = regr.predict(test_x) # predict is a keyword from sk learn module
mae= np.mean(np.absolute(test_y_ - test_y))
mae_=mae/21613
mse=np.mean((test_y_ - test_y) ** 2)
mse_=mse/21613
print("Mean absolute error: " , mae_)
print("Residual sum of squares (MSE): " ,mse_ )
# Out:
# Coefficients:  [[0.7739767]]
# Intercept:  [528081.1404475]
# Mean absolute error:  10.625294828936248
# Residual sum of squares (MSE):  5927072.61627958

# %%
cdf = dff[['price','sqft_basement']]

from sklearn.model_selection import train_test_split
X_train1,X_test1,y_train1,y_test1=train_test_split(cdf,cdf,test_size=.2,random_state=4);

from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x1 = np.asanyarray(X_train1[['sqft_basement']])
train_y1 = np.asanyarray(X_train1[['price']])
regr.fit(train_x1, train_y1)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)

plt.scatter(X_train1.sqft_basement, X_train1.price  ,  color='blue')
plt.plot(train_x1, regr.coef_[0][0]*train_x1 + regr.intercept_[0], '-r')
plt.xlabel("Sqft_basement")
plt.ylabel("Price")
test_x = np.asanyarray(X_test[['sqft_basement']])
test_y = np.asanyarray(X_test[['price']]) #this is the y' (predicted value)
test_y_ = regr.predict(test_x) # predict is a keyword from sk learn module
mae= np.mean(np.absolute(test_y_ - test_y))
mae_=mae/21613
mse=np.mean((test_y_ - test_y) ** 2)
mse_=mse/21613
print("Mean absolute error: " , mae_)
print("Residual sum of squares (MSE): " ,mse_ )
# Out:
# Coefficients:  [[273.29121377]]
# Intercept:  [459646.53758894]
# Mean absolute error:  10.299508809345143
# Residual sum of squares (MSE):  5427892.6349292

# %%
cdf = dff[['price','sqft_above']]

from sklearn.model_selection import train_test_split
X_train1,X_test1,y_train1,y_test1=train_test_split(cdf,cdf,test_size=.2,random_state=4);

from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x1 = np.asanyarray(X_train1[['sqft_above']])
train_y1 = np.asanyarray(X_train1[['price']])
regr.fit(train_x1, train_y1)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)

plt.scatter(X_train1.sqft_above, X_train1.price  ,  color='blue')
plt.plot(train_x1, regr.coef_[0][0]*train_x1 + regr.intercept_[0], '-r')
plt.xlabel("Sqft_above")
plt.ylabel("Price")
test_x = np.asanyarray(X_test[['sqft_above']])
test_y = np.asanyarray(X_test[['price']]) #this is the y' (predicted value)
test_y_ = regr.predict(test_x) # predict is a keyword from sk learn module
mae= np.mean(np.absolute(test_y_ - test_y))
mae_=mae/21613
mse=np.mean((test_y_ - test_y) ** 2)
mse_=mse/21613
print("Mean absolute error: " , mae_)
print("Residual sum of squares (MSE): " ,mse_ )
# Out:
# Coefficients:  [[271.07584553]]
# Intercept:  [55969.4706309]
# Mean absolute error:  8.886516225680174
# Residual sum of squares (MSE):  3861690.58196073
